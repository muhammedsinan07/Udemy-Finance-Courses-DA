# %%
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import scipy as sp
from scipy import stats

# %%
udemy = pd.read_csv('C:\data analytics\pandas_docs/udemy_output_All_Finance__Accounting_p1_p626.csv')
udemy
# Out:
#             id                                              title  \
# 0       762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1       937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2      1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3       648826         The Complete Financial Analyst Course 2020
# 4       637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...        ...                                                ...
# 13603  3005408                      מושגים בסיסיים באופציות חלק ב
# 13604  3467284                            Programa de Integridade
# 13605  3368222  Goodwill and Method of Calculating Goodwill (A...
# 13606  3211345                                Poderoso Investidor
# 13607  2935720         Acabou a Previdência e agora? -  Volume 03
#
#                                                      url  is_paid  \
# 0                     /course/the-complete-sql-bootcamp/     True
# ...

# %%
udemy.shape
# Out:
# (13608, 20)

# %%
udemy.columns
# Out:
# Index(['id', 'title', 'url', 'is_paid', 'num_subscribers', 'avg_rating',
#        'avg_rating_recent', 'rating', 'num_reviews', 'is_wishlisted',
#        'num_published_lectures', 'num_published_practice_tests', 'created',
#        'published_time', 'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string'],
#       dtype='object')

# %%
udemy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13608 entries, 0 to 13607
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            13608 non-null  int64
#  1   title                         13608 non-null  object
#  2   url                           13608 non-null  object
#  3   is_paid                       13608 non-null  bool
#  4   num_subscribers               13608 non-null  int64
#  5   avg_rating                    13608 non-null  float64
#  6   avg_rating_recent             13608 non-null  float64
#  7   rating                        13608 non-null  float64
#  8   num_reviews                   13608 non-null  int64
#  9   is_wishlisted                 13608 non-null  bool
#  10  num_published_lectures        13608 non-null  int64
#  11  num_published_practice_tests  13608 non-null  int64
# ...

# %%
udemy.head(3)
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
#
#                                   url  is_paid  num_subscribers  avg_rating  \
# 0  /course/the-complete-sql-bootcamp/     True           295509     4.66019
# 1                  /course/tableau10/     True           209070     4.58956
# 2         /course/pmp-pmbok6-35-pdus/     True           155282     4.59491
#
#    avg_rating_recent   rating  num_reviews  is_wishlisted  \
# 0            4.67874  4.67874        78006          False
# 1            4.60015  4.60015        54581          False
# 2            4.59326  4.59326        52653          False
#
#    num_published_lectures  num_published_practice_tests               created  \
# 0                      84                             0  2016-02-14T22:57:48Z
# ...

# %%
udemy.tail(3)
# Out:
#             id                                              title  \
# 13605  3368222  Goodwill and Method of Calculating Goodwill (A...
# 13606  3211345                                Poderoso Investidor
# 13607  2935720         Acabou a Previdência e agora? -  Volume 03
#
#                                                      url  is_paid  \
# 13605  /course/goodwill-and-method-of-calculating-goo...    False
# 13606                       /course/poderoso-investidor/    False
# 13607    /course/acabou-a-previdencia-e-agora-volume-03/     True
#
#        num_subscribers  avg_rating  avg_rating_recent  rating  num_reviews  \
# 13605               47         0.0                0.0     0.0            0
# 13606               48         0.0                0.0     0.0            0
# 13607                0         0.0                0.0     0.0            0
#
#        is_wishlisted  num_published_lectures  num_published_practice_tests  \
# ...

# %% [markdown]
# - Course info
# - Course Performance info
# - Course Price info

# %% [markdown]
# 1. Course Info
#     - id
#     - title
#     - url
#     - is_paid
#     - num_published_lectures
#     - num_published_practice_tests
#     - created
#     - published_time
#
# 2. Course Performance info
#     - num_subscribers
#     - avg_rating
#     - avg_rating_recent
#     - rating
#     - num_reviews
#     - is_wishlisted
#     -
# 3. Course Price info
#     - discount_price__amount
#     - discount_price__currency
#     - discount_price__price_string
#     - price_detail__amount
#     - price_detail__currency
#     - price_detail__price_string

# %%
udemy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13608 entries, 0 to 13607
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            13608 non-null  int64
#  1   title                         13608 non-null  object
#  2   url                           13608 non-null  object
#  3   is_paid                       13608 non-null  bool
#  4   num_subscribers               13608 non-null  int64
#  5   avg_rating                    13608 non-null  float64
#  6   avg_rating_recent             13608 non-null  float64
#  7   rating                        13608 non-null  float64
#  8   num_reviews                   13608 non-null  int64
#  9   is_wishlisted                 13608 non-null  bool
#  10  num_published_lectures        13608 non-null  int64
#  11  num_published_practice_tests  13608 non-null  int64
# ...

# %% [markdown]
# - There are missing values only in price related features
# - There are 2 boolean fields namely,`is_paid` and `is_wishlisted`

# %% [markdown]
# ### Data Cleaning and Processing

# %%
udemy.head()
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
#
#                                                  url  is_paid  \
# 0                 /course/the-complete-sql-bootcamp/     True
# 1                                 /course/tableau10/     True
# 2                        /course/pmp-pmbok6-35-pdus/     True
# 3     /course/the-complete-financial-analyst-course/     True
# 4  /course/an-entire-mba-in-1-courseaward-winning...     True
#
#    num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           295509     4.66019            4.67874  4.67874        78006
# ...

# %%
udemy['id'].unique().size
# Out:
# 13608

# %% [markdown]
# - since the no.of unique values inside Id feature we can conclude that there is not duplicate values

# %%
udemy.describe(include='all')
# Out:
#                   id                                              title  \
# count   1.360800e+04                                              13608
# unique           NaN                                              13563
# top              NaN  Shopify Dropshipping - Scale to 7 figures with...
# freq             NaN                                                  2
# mean    1.681721e+06                                                NaN
# std     9.539271e+05                                                NaN
# min     2.762000e+03                                                NaN
# 25%     8.580862e+05                                                NaN
# 50%     1.623421e+06                                                NaN
# 75%     2.503720e+06                                                NaN
# max     3.486006e+06                                                NaN
#
#                                        url is_paid  num_subscribers  \
# ...

# %% [markdown]
# - since url feature contains all unique values we can say that there is no duplicate courses(even though some courses shares the same title)

# %%
udemy['published_time']
# Out:
# 0        2016-04-06T05:16:11Z
# 1        2016-08-23T16:59:49Z
# 2        2017-11-14T23:58:14Z
# 3        2016-01-21T01:38:48Z
# 4        2016-01-11T21:39:33Z
#                  ...
# 13603    2020-04-23T02:06:55Z
# 13604    2020-09-03T15:26:47Z
# 13605    2020-07-31T12:14:40Z
# 13606    2020-07-15T10:35:38Z
# 13607    2020-04-02T16:33:32Z
# Name: published_time, Length: 13608, dtype: object

# %% [markdown]
# - Features to Drop
#     - id
#     - title
#     - url
#     - is_wishlisted
#     - created
#     - published_time
#     - num_published_practice_tests

# %%
udemy['num_published_practice_tests'].value_counts()
# Out:
# num_published_practice_tests
# 0    13008
# 2      214
# 1      202
# 6       67
# 5       43
# 3       39
# 4       35
# Name: count, dtype: int64

# %%
original_df = udemy.copy()
all_columns_dataset=udemy.copy()

# %%
udemy = udemy.drop(columns=['id','title','url','is_wishlisted','created','published_time','num_published_practice_tests'])

# %%
udemy
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 0         True           295509     4.66019            4.67874  4.67874
# 1         True           209070     4.58956            4.60015  4.60015
# 2         True           155282     4.59491            4.59326  4.59326
# 3         True           245860     4.54407            4.53772  4.53772
# 4         True           374836     4.47080            4.47173  4.47173
# ...        ...              ...         ...                ...      ...
# 13603    False               47     0.00000            0.00000  0.00000
# 13604    False               19     0.00000            0.00000  0.00000
# 13605    False               47     0.00000            0.00000  0.00000
# 13606    False               48     0.00000            0.00000  0.00000
# 13607     True                0     0.00000            0.00000  0.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# ...

# %%
udemy.columns
# Out:
# Index(['is_paid', 'num_subscribers', 'avg_rating', 'avg_rating_recent',
#        'rating', 'num_reviews', 'num_published_lectures',
#        'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string'],
#       dtype='object')

# %%
udemy.shape
# Out:
# (13608, 13)

# %%
udemy.isnull().sum()
# Out:
# is_paid                            0
# num_subscribers                    0
# avg_rating                         0
# avg_rating_recent                  0
# rating                             0
# num_reviews                        0
# num_published_lectures             0
# discount_price__amount          1403
# discount_price__currency        1403
# discount_price__price_string    1403
# price_detail__amount             497
# price_detail__currency           497
# price_detail__price_string       497
# dtype: int64

# %% [markdown]
# - we can check if the number of reviews for any course is greater than number of subscribers.At most number of reviews==number of subscribers

# %%
udemy[udemy['num_reviews'] > udemy['num_subscribers']]
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 10898     True                0        3.00            3.00000  3.00000
# 10950     True                0        5.00            5.00000  5.00000
# 12905     True                0        2.75            3.19403  3.19403
# 12942     True                1        2.50            2.50000  2.50000
# 13049     True                0        5.00            5.00000  5.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# 10898            1                      12                   455.0
# 10950            1                       0                     NaN
# 12905            2                       0                   455.0
# 12942            2                       8                     NaN
# 13049            1                      13                     NaN
#
#       discount_price__currency discount_price__price_string  \
# 10898                      INR                         ₹455
# ...

# %%
reviews_subscribers = (udemy['num_reviews'] > udemy['num_subscribers'])
reviews_subscribers.sum()
# Out:
# 5

# %% [markdown]
# - there are 5 courses where the number of reviews is greater than number of subscribers

# %%
udemy[reviews_subscribers]
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 10898     True                0        3.00            3.00000  3.00000
# 10950     True                0        5.00            5.00000  5.00000
# 12905     True                0        2.75            3.19403  3.19403
# 12942     True                1        2.50            2.50000  2.50000
# 13049     True                0        5.00            5.00000  5.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# 10898            1                      12                   455.0
# 10950            1                       0                     NaN
# 12905            2                       0                   455.0
# 12942            2                       8                     NaN
# 13049            1                      13                     NaN
#
#       discount_price__currency discount_price__price_string  \
# 10898                      INR                         ₹455
# ...

# %% [markdown]
# - we can delete all these courses , otherwise it may lead us in a wrong direction

# %%
#removing all those rows where num reviews is greater than num subscribes
index_list = udemy[reviews_subscribers].index
udemy = udemy.drop(index=index_list)
all_columns_dataset = all_columns_dataset.drop(index=index_list)

# %%
udemy.shape
# Out:
# (13603, 13)

# %%
udemy = udemy.reset_index(drop=True) #check why we are passing this drop arguement
all_columns_dataset = all_columns_dataset.reset_index()

# %%
udemy
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 0         True           295509     4.66019            4.67874  4.67874
# 1         True           209070     4.58956            4.60015  4.60015
# 2         True           155282     4.59491            4.59326  4.59326
# 3         True           245860     4.54407            4.53772  4.53772
# 4         True           374836     4.47080            4.47173  4.47173
# ...        ...              ...         ...                ...      ...
# 13598    False               47     0.00000            0.00000  0.00000
# 13599    False               19     0.00000            0.00000  0.00000
# 13600    False               47     0.00000            0.00000  0.00000
# 13601    False               48     0.00000            0.00000  0.00000
# 13602     True                0     0.00000            0.00000  0.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# ...

# %%
udemy.iloc[10898]
# Out:
# is_paid                           True
# num_subscribers                      7
# avg_rating                         5.0
# avg_rating_recent                  5.0
# rating                             5.0
# num_reviews                          1
# num_published_lectures              13
# discount_price__amount           455.0
# discount_price__currency           INR
# discount_price__price_string      ₹455
# price_detail__amount            8640.0
# price_detail__currency             INR
# price_detail__price_string      ₹8,640
# Name: 10898, dtype: object

# %%
reviews_subscribers = (udemy['num_reviews'] > udemy['num_subscribers'])
reviews_subscribers.sum()
# Out:
# 0

# %% [markdown]
# - So the invalid courses were removed by the dataset

# %% [markdown]
# #### Examining Price Related Columns

# %%
udemy.columns
# Out:
# Index(['is_paid', 'num_subscribers', 'avg_rating', 'avg_rating_recent',
#        'rating', 'num_reviews', 'num_published_lectures',
#        'discount_price__amount', 'discount_price__currency',
#        'discount_price__price_string', 'price_detail__amount',
#        'price_detail__currency', 'price_detail__price_string'],
#       dtype='object')

# %%
price_related_columns = ['discount_price__amount', 'discount_price__currency',
       'discount_price__price_string', 'price_detail__amount',
       'price_detail__currency', 'price_detail__price_string']

# %%
price_related_columns
# Out:
# ['discount_price__amount',
#  'discount_price__currency',
#  'discount_price__price_string',
#  'price_detail__amount',
#  'price_detail__currency',
#  'price_detail__price_string']

# %%
udemy[price_related_columns].sample(10)
# Out:
#       discount_price__amount discount_price__currency  \
# 8773                   455.0                      INR
# 5289                   455.0                      INR
# 5656                   455.0                      INR
# 4412                   455.0                      INR
# 977                    455.0                      INR
# 3257                   455.0                      INR
# 2637                   455.0                      INR
# 6575                   455.0                      INR
# 2480                   455.0                      INR
# 7189                   455.0                      INR
#
#      discount_price__price_string  price_detail__amount  \
# 8773                         ₹455                8640.0
# 5289                         ₹455                5760.0
# 5656                         ₹455                2240.0
# 4412                         ₹455                6080.0
# 977                          ₹455                4800.0
# ...

# %%
udemy[['discount_price__currency','price_detail__currency']].describe()
# Out:
#        discount_price__currency price_detail__currency
# count                     12203                  13106
# unique                        1                      1
# top                         INR                    INR
# freq                      12203                  13106

# %%
udemy.discount_price__amount.value_counts()
# Out:
# discount_price__amount
# 455.0     11408
# 468.0       135
# 700.0        86
# 3200.0       61
# 462.0        47
# 481.0        44
# 800.0        39
# 520.0        34
# 474.0        30
# 1600.0       27
# 488.0        27
# 640.0        24
# 494.0        22
# 480.0        17
# 2400.0       16
# 960.0        13
# 720.0        12
# 1440.0       11
# 2880.0       10
# 2080.0        9
# 1920.0        8
# 1520.0        8
# 1200.0        8
# 500.0         7
# 1120.0        7
# 2240.0        7
# 1280.0        6
# 514.0         6
# 2720.0        6
# 507.0         5
# 2000.0        5
# 560.0         5
# 2160.0        5
# 1360.0        5
# 1040.0        5
# 1760.0        4
# 1680.0        3
# 880.0         3
# 3040.0        3
# 2800.0        3
# 2640.0        2
# 2960.0        2
# 2560.0        2
# 3120.0        2
# 2320.0        2
# 552.0         2
# 533.0         2
# 546.0         2
# 540.0         2
# 1840.0        1
# 760.0         1
# 2480.0        1
# 611.0         1
# ...

# %% [markdown]
# - since the `discount_price__price_string` and `price_detail__price_string` are the string counterparts of `discount_price__amount` and `price_detail__amount` respectively we can get rid of them
# - discount_price__currency and 	price_detail__currency features are contains only the value 'INR' - most of the rows of discount_price__amount column contains 455

# %%
# droping unwanted columns
udemy = udemy.drop(columns=['discount_price__price_string','price_detail__price_string','discount_price__currency','price_detail__currency'])

# %%
udemy.head()
# Out:
#    is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 0     True           295509     4.66019            4.67874  4.67874
# 1     True           209070     4.58956            4.60015  4.60015
# 2     True           155282     4.59491            4.59326  4.59326
# 3     True           245860     4.54407            4.53772  4.53772
# 4     True           374836     4.47080            4.47173  4.47173
#
#    num_reviews  num_published_lectures  discount_price__amount  \
# 0        78006                      84                   455.0
# 1        54581                      78                   455.0
# 2        52653                     292                   455.0
# 3        46447                     338                   455.0
# 4        41630                      83                   455.0
#
#    price_detail__amount
# 0                8640.0
# 1                8640.0
# 2                8640.0
# 3                8640.0
# 4                8640.0

# %%
udemy.shape
# Out:
# (13603, 9)

# %%
price_related_columns = ['discount_price__amount','price_detail__amount']

# %% [markdown]
# #### Checking `discount_price_amount`

# %%
udemy['discount_price__amount']
# Out:
# 0        455.0
# 1        455.0
# 2        455.0
# 3        455.0
# 4        455.0
#          ...
# 13598      NaN
# 13599      NaN
# 13600      NaN
# 13601      NaN
# 13602      NaN
# Name: discount_price__amount, Length: 13603, dtype: float64

# %% [markdown]
# #### Retrieving instances where the values are not 455 and Nan

# %%
udemy['discount_price__amount'].notna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 13598    False
# 13599    False
# 13600    False
# 13601    False
# 13602    False
# Name: discount_price__amount, Length: 13603, dtype: bool

# %%
series_bool_discount_price = (udemy['discount_price__amount'] != 455) & (udemy['discount_price__amount'].notna())

# %%
not_455_not_na = series_bool_discount_price.sum()
not_455_not_na
# Out:
# 795

# %%
series_bool_discount_price
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13598    False
# 13599    False
# 13600    False
# 13601    False
# 13602    False
# Name: discount_price__amount, Length: 13603, dtype: bool

# %% [markdown]
# #### checking the percentage of discount price rows that are not equal to 455 not Nan

# %%
not_455_not_na_percentage = (not_455_not_na/udemy['discount_price__amount'].size)*100
np.around(not_455_not_na_percentage,2)
# Out:
# 5.84

# %% [markdown]
# - just 5.84 % only differ from the 455 and Nan in our discount feature
# - udemy offers a standard discount

# %%
udemy
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent   rating  \
# 0         True           295509     4.66019            4.67874  4.67874
# 1         True           209070     4.58956            4.60015  4.60015
# 2         True           155282     4.59491            4.59326  4.59326
# 3         True           245860     4.54407            4.53772  4.53772
# 4         True           374836     4.47080            4.47173  4.47173
# ...        ...              ...         ...                ...      ...
# 13598    False               47     0.00000            0.00000  0.00000
# 13599    False               19     0.00000            0.00000  0.00000
# 13600    False               47     0.00000            0.00000  0.00000
# 13601    False               48     0.00000            0.00000  0.00000
# 13602     True                0     0.00000            0.00000  0.00000
#
#        num_reviews  num_published_lectures  discount_price__amount  \
# ...

# %%
udemy.shape
# Out:
# (13603, 9)

# %%
# droping discount_price_amount feature
udemy.drop(['discount_price__amount'],axis=1,inplace=True)

# %%
udemy.shape
# Out:
# (13603, 8)

# %%
udemy.columns
# Out:
# Index(['is_paid', 'num_subscribers', 'avg_rating', 'avg_rating_recent',
#        'rating', 'num_reviews', 'num_published_lectures',
#        'price_detail__amount'],
#       dtype='object')

# %% [markdown]
# ### Examining price_detail_amount

# %%
def_price_and_is_paid = udemy[['price_detail__amount','is_paid']]

# %%
def_price_and_is_paid
# Out:
#        price_detail__amount  is_paid
# 0                    8640.0     True
# 1                    8640.0     True
# 2                    8640.0     True
# 3                    8640.0     True
# 4                    8640.0     True
# ...                     ...      ...
# 13598                   NaN    False
# 13599                   NaN    False
# 13600                   NaN    False
# 13601                   NaN    False
# 13602                   NaN     True
#
# [13603 rows x 2 columns]

# %%
def_price_and_is_paid[def_price_and_is_paid['is_paid']==False].sample(5)
# Out:
#        price_detail__amount  is_paid
# 13550                   NaN    False
# 13532                   NaN    False
# 11577                   NaN    False
# 13501                   NaN    False
# 11646                   NaN    False

# %%
def_price_and_is_paid[def_price_and_is_paid['is_paid']==True].sample(5)
# Out:
#        price_detail__amount  is_paid
# 422                  5440.0     True
# 3160                 1600.0     True
# 10787                8640.0     True
# 2032                 1280.0     True
# 3412                 1600.0     True

# %% [markdown]
# - Nan values inside price details column is for Unpaid Courses
# - Instead of 0 here the values are missing

# %%
#checking is there any data point with any price when the course is free 
((def_price_and_is_paid['is_paid']==False) & (def_price_and_is_paid['price_detail__amount'].notna())).sum()
# Out:
# 0

# %%
#checking is there any data point with price NAN when the course is paid 
((def_price_and_is_paid['is_paid']==True) & (def_price_and_is_paid['price_detail__amount'].isna())).sum()
# Out:
# 1

# %% [markdown]
# - There is one course which is paid but its price is not present

# %%
#checking is there any data point with price 0 when the course is paid 
((def_price_and_is_paid['is_paid']==True) & (def_price_and_is_paid['price_detail__amount']==0)).sum()
# Out:
# 0

# %%
def_price_and_is_paid[def_price_and_is_paid['price_detail__amount']==0]
# Out:
# Empty DataFrame
# Columns: [price_detail__amount, is_paid]
# Index: []

# %%
#checking for the invalid data point
udemy[(udemy['is_paid']==True) & (udemy['price_detail__amount'].isna())]
# Out:
#        is_paid  num_subscribers  avg_rating  avg_rating_recent  rating  \
# 13602     True                0         0.0                0.0     0.0
#
#        num_reviews  num_published_lectures  price_detail__amount
# 13602            0                      14                   NaN

# %%
all_columns_dataset[(all_columns_dataset['is_paid']==True) & (all_columns_dataset['price_detail__amount'].isna())]
# Out:
#        index       id                                       title  \
# 13602  13607  2935720  Acabou a Previdência e agora? -  Volume 03
#
#                                                    url  is_paid  \
# 13602  /course/acabou-a-previdencia-e-agora-volume-03/     True
#
#        num_subscribers  avg_rating  avg_rating_recent  rating  num_reviews  \
# 13602                0         0.0                0.0     0.0            0
#
#        ...  num_published_lectures  num_published_practice_tests  \
# 13602  ...                      14                             0
#
#                     created        published_time discount_price__amount  \
# 13602  2020-03-30T19:10:58Z  2020-04-02T16:33:32Z                    NaN
#
#        discount_price__currency discount_price__price_string  \
# 13602                       NaN                          NaN
#
#       price_detail__amount  price_detail__currency price_detail__price_string
# ...

# %%
#deleting the course with invalid entry
all_columns_dataset = all_columns_dataset.drop(index=[13602])

# %%
all_columns_dataset[(all_columns_dataset['is_paid']==True) & (all_columns_dataset['price_detail__amount'].isna())]
# Out:
# Empty DataFrame
# Columns: [index, id, title, url, is_paid, num_subscribers, avg_rating, avg_rating_recent, rating, num_reviews, is_wishlisted, num_published_lectures, num_published_practice_tests, created, published_time, discount_price__amount, discount_price__currency, discount_price__price_string, price_detail__amount, price_detail__currency, price_detail__price_string]
# Index: []
#
# [0 rows x 21 columns]

# %%
all_columns_dataset
# Out:
#        index       id                                              title  \
# 0          0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1          1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2          2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3          3   648826         The Complete Financial Analyst Course 2020
# 4          4   637930  An Entire MBA in 1 Course:Award Winning Busine...
# ...      ...      ...                                                ...
# 13597  13602  3397774                             מסחר אוטומטי בשוק ההון
# 13598  13603  3005408                      מושגים בסיסיים באופציות חלק ב
# 13599  13604  3467284                            Programa de Integridade
# 13600  13605  3368222  Goodwill and Method of Calculating Goodwill (A...
# 13601  13606  3211345                                Poderoso Investidor
#
#                                                      url  is_paid  \
# ...

# %%
#now we can replace all Nan values into zero
udemy['price_detail__amount'] = udemy['price_detail__amount'].fillna(0)

# %%
udemy['price_detail__amount'].isnull().sum()
# Out:
# 0

# %%
udemy['price_detail__amount'].value_counts()
# Out:
# price_detail__amount
# 8640.0     3213
# 1280.0     3031
# 3200.0     1033
# 6400.0      984
# 1600.0      776
# 1920.0      689
# 0.0         497
# 2560.0      451
# 2240.0      405
# 6080.0      285
# 4800.0      251
# 2880.0      241
# 5120.0      183
# 3840.0      182
# 5760.0      166
# 4480.0      154
# 8000.0      142
# 3520.0      125
# 12800.0     122
# 7680.0       94
# 4160.0       93
# 8320.0       71
# 5440.0       67
# 6720.0       67
# 7040.0       62
# 9600.0       52
# 8960.0       52
# 7360.0       41
# 9280.0       34
# 10240.0       8
# 12480.0       8
# 11840.0       6
# 12160.0       4
# 11520.0       4
# 9920.0        3
# 11200.0       3
# 10560.0       2
# 10880.0       2
# Name: count, dtype: int64

# %% [markdown]
# - now we dont have any missing values inside our price detail column and hence in the enitire dataset

# %%
udemy.isnull().sum()
# Out:
# is_paid                   0
# num_subscribers           0
# avg_rating                0
# avg_rating_recent         0
# rating                    0
# num_reviews               0
# num_published_lectures    0
# price_detail__amount      0
# dtype: int64

# %%
#is paid feature is not releavant anymmore since we can derive the price variation from the price detail feaure itself

# %%
udemy = udemy.rename(columns={'price_detail__amount':'price'})

# %%
udemy.columns
# Out:
# Index(['is_paid', 'num_subscribers', 'avg_rating', 'avg_rating_recent',
#        'rating', 'num_reviews', 'num_published_lectures', 'price'],
#       dtype='object')

# %%
udemy.dtypes
# Out:
# is_paid                      bool
# num_subscribers             int64
# avg_rating                float64
# avg_rating_recent         float64
# rating                    float64
# num_reviews                 int64
# num_published_lectures      int64
# price                     float64
# dtype: object

# %% [markdown]
# ### More Exploration

# %%
udemy.describe()
# Out:
#        num_subscribers    avg_rating  avg_rating_recent        rating  \
# count     13603.000000  13603.000000       13603.000000  13603.000000
# mean       2848.056826      3.923394           3.912305      3.912305
# std        9439.442264      1.031259           1.039226      1.039226
# min           0.000000      0.000000           0.000000      0.000000
# 25%          62.000000      3.800000           3.787795      3.787795
# 50%         534.000000      4.194440           4.181800      4.181800
# 75%        2281.500000      4.450000           4.452090      4.452090
# max      374836.000000      5.000000           5.000000      5.000000
#
#         num_reviews  num_published_lectures         price
# count  13603.000000            13603.000000  13603.000000
# mean     243.258693               32.234213   4477.506432
# std     1581.249647               42.771812   3173.248776
# min        0.000000                0.000000      0.000000
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
#distribution of course price
sns.displot(udemy['price'],kde=True)

# %%
udemy['price'].between(1000,2000).sum()
# Out:
# 4496

# %%
((udemy['price']>1500) & (udemy['price']<2000)).sum()
# Out:
# 1465

# %%
udemy['price'].value_counts()
# Out:
# price
# 8640.0     3213
# 1280.0     3031
# 3200.0     1033
# 6400.0      984
# 1600.0      776
# 1920.0      689
# 0.0         497
# 2560.0      451
# 2240.0      405
# 6080.0      285
# 4800.0      251
# 2880.0      241
# 5120.0      183
# 3840.0      182
# 5760.0      166
# 4480.0      154
# 8000.0      142
# 3520.0      125
# 12800.0     122
# 7680.0       94
# 4160.0       93
# 8320.0       71
# 5440.0       67
# 6720.0       67
# 7040.0       62
# 9600.0       52
# 8960.0       52
# 7360.0       41
# 9280.0       34
# 10240.0       8
# 12480.0       8
# 11840.0       6
# 12160.0       4
# 11520.0       4
# 9920.0        3
# 11200.0       3
# 10560.0       2
# 10880.0       2
# Name: count, dtype: int64

# %%
# checking for outliers
sns.boxplot(x=udemy['price'])
plt.show()

# %% [markdown]
# - There is no outliers in our dataset

# %%
udemy.columns
# Out:
# Index(['is_paid', 'num_subscribers', 'avg_rating', 'avg_rating_recent',
#        'rating', 'num_reviews', 'num_published_lectures', 'price'],
#       dtype='object')

# %%
sns.displot(udemy['num_subscribers'],kde=True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - heavy right skewness in the dataset
# - some courses are heavily popular may be the one reason for this skewed data

# %%
sns.displot(udemy['avg_rating'],kde=True)

# %%
sns.displot(udemy['avg_rating_recent'],kde=True)

# %%
sns.displot(udemy['rating'],kde=True)

# %% [markdown]
# - All the distributions related to rating looks very similar

# %%
sns.displot(udemy['num_reviews'],kde=True)
plt.xticks(rotation=40)
plt.show()

# %%
udemy['num_reviews'].describe()
# Out:
# count    13603.000000
# mean       243.258693
# std       1581.249647
# min          0.000000
# 25%          7.000000
# 50%         24.000000
# 75%         87.000000
# max      78006.000000
# Name: num_reviews, dtype: float64

# %% [markdown]
# - 75% of the data lies below 87 while the max value is 78006
# - This may due to the popularity of certain courses(number of subscribers)

# %%
sns.displot(udemy['num_published_lectures'],kde=True)

# %% [markdown]
# - Right skewed data

# %% [markdown]
# ### Examine Rating Related Features

# %%
udemy.columns
# Out:
# Index(['is_paid', 'num_subscribers', 'avg_rating', 'avg_rating_recent',
#        'rating', 'num_reviews', 'num_published_lectures', 'price'],
#       dtype='object')

# %%
udemy[['rating','avg_rating','avg_rating_recent']].sample(10)
# Out:
#         rating  avg_rating  avg_rating_recent
# 8423   4.31906      4.5000            4.31906
# 11696  4.27814      4.2750            4.27814
# 3081   4.15762      4.0000            4.15762
# 4066   3.94216      4.2000            3.94216
# 5915   3.88933      3.9000            3.88933
# 12043  4.53731      4.4500            4.53731
# 10946  5.00000      5.0000            5.00000
# 10334  4.08592      4.0000            4.08592
# 13508  4.80859      4.8125            4.80859
# 9731   4.29338      4.3600            4.29338

# %%
(udemy['rating']==udemy['avg_rating_recent']).sum()
# Out:
# 13603

# %% [markdown]
# - we are verified that both the rating and average recent rating features are same

# %%
# we can drop one of the column
udemy=udemy.drop('rating',axis=1)

# %%
udemy.columns
# Out:
# Index(['is_paid', 'num_subscribers', 'avg_rating', 'avg_rating_recent',
#        'num_reviews', 'num_published_lectures', 'price'],
#       dtype='object')

# %%
#let's findout correlation between 'avg_rating' and  'avg_rating_recent'
correlation_coefficient = stats.pearsonr(udemy['avg_rating'],udemy['avg_rating_recent'])[0]
np.around(correlation_coefficient,2)
# Out:
# 0.99

# %% [markdown]
# - The correlation between avg rating and recent avg rating is 0.99
# - We can predict avrg rating from recent average rating
# - hence we can remove one of them

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.heatmap(udemy.corr(),annot=True)
plt.show()

# %%
sns.pairplot(udemy)
plt.show()
